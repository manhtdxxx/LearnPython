# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# ### PREPARE DATA

# %%
df = pd.read_excel('score.xlsx',sheet_name='Sheet2')
print(df)
print('-'*100)

# đầu vào
X = df[['so_gio_hoc', 'do_tap_trung', 'pp_hoc', 'tuoi']].values

# đầu ra
Y = df.diem.values

# Chia X,Y thành 2 bộ training & testing
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size = 0.6, random_state=42)
print(X_train)
print()
print(X_test)
print('-'*100)
print(Y_train)
print()
print(Y_test)
# Out:
#    so_gio_hoc  do_tap_trung  pp_hoc  tuoi  diem
# 0           2             5       1    20    30
# 1           3             4       2    25    35
# 2           4             2       4    40    40
# 3           5             4       3    30    44
# 4           6             2       2    20    48
# 5           7             3       2    30    60
# 6           8             5       1    30    66
# 7           9             2       3    50    70
# 8          10             1       2    15    75
# ----------------------------------------------------------------------------------------------------
# [[10  1  2 15]
#  [ 4  2  4 40]
#  [ 6  2  2 20]
#  [ 5  4  3 30]
#  [ 8  5  1 30]]
#
# [[ 9  2  3 50]
#  [ 3  4  2 25]
#  [ 7  3  2 30]
#  [ 2  5  1 20]]
# ----------------------------------------------------------------------------------------------------
# [75 40 48 44 66]
#
# [70 35 60 30]

# %% [markdown]
# ### SELECT & TRAIN MODEL

# %%
# SELECT
LR = lm.LinearRegression()

# TRAIN
LR.fit(X_train,Y_train)

# CHECK QUY TẮC: y = a.x + b.y + c.z + d.e + f
a = LR.coef_
b = LR.intercept_
print('coefficients:',a)
print('intercept:',b)
# Out:
# coefficients: [ 7.17647059e+00  2.35780287e-15 -2.35294118e-01  3.41176471e-01]
# intercept: -1.4117647058823835

# %% [markdown]
# ### TEST

# %%
Yp_train = LR.predict(X_train)

print('PREDICTED TRAINING Y:',Yp_train)
print('ACTUAL TRAINING Y:   ',Y_train)
print('-'*100)

plt.plot(X_train,Y_train,'r*',label='Actual Training Y')
plt.plot(X_train,Yp_train,'b-.',label='Predicted Training Y')
plt.legend(loc=0)

# Đồ thị 2D không thể biểu diễn được, vì 4 biến nên cần đồ thị 4D
# Không phân biệt được đâu là x,y,z,e
# Out:
# PREDICTED TRAINING Y: [75. 40. 48. 44. 66.]
# ACTUAL TRAINING Y:    [75 40 48 44 66]
# ----------------------------------------------------------------------------------------------------

# %%
Yp_test = LR.predict(X_test)

print('PREDICTED TESTING Y:',Yp_test)
print('ACTUAL TESTING Y:   ',Y_test)
print('-'*100)

plt.plot(X_test,Y_test,'r*',label='Actual Testing Y')
plt.plot(X_test,Yp_test,'b-.',label='Predicted Testing Y')
plt.legend(loc=0)

# Đồ thị 2D không thể biểu diễn được, vì 4 biến nên cần đồ thị 4D
# Không phân biệt được đâu là x,y,z,e
# Out:
# PREDICTED TESTING Y: [79.52941176 28.17647059 58.58823529 19.52941176]
# ACTUAL TESTING Y:    [70 35 60 30]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### EVALUATE MODEL

# %%
MSE1 = mean_squared_error(Y_test,Yp_test) # hay variance
MSE2 = mean_squared_error(Y_train,Yp_train)
print('MSE OF TESTING DATA:',MSE1)
print('MSE OF TRAINING DATA:',MSE2)
print('-'*100)

R2_1 = r2_score(Y_test,Yp_test) # R_squared
R2_2 = r2_score(Y_train,Yp_train)
print('R2 OF TESTING DATA:',R2_1)
print('R2 OF TRAINING DATA:',R2_2)
print('-'*100)

# KẾT LUẬN
print('==> OVERFIT')


# MAE,MSE,RMSE gần về 0 càng tốt
# R2 gần về 1 càng tốt
# Out:
# MSE OF TESTING DATA: 62.24913494809691
# MSE OF TRAINING DATA: 1.8175355256292112e-28
# ----------------------------------------------------------------------------------------------------
# R2 OF TESTING DATA: 0.7774332605207708
# R2 OF TRAINING DATA: 1.0
# ----------------------------------------------------------------------------------------------------
# ==> OVERFIT

# %% [markdown]
# ### IMPLEMENT

# %%
Y_moi = LR.predict([[15,3,2,50]])
print(Y_moi)
# Out:
# [122.82352941]
